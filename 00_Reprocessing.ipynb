# %% [markdown]
# ## Preprocessing Model

# %%
import pandas as pd
import numpy as np
import string
import nltk
from nltk.tokenize import RegexpTokenizer
import re
from nltk.stem import PorterStemmer

def preprocess_alg(text):
    
    #lowercase
    text = text.lower()  
    
    #tokenization & remove punctuation
    tokenizer = RegexpTokenizer(r'\w+')  
    tokens = tokenizer.tokenize(text)
    
    #remove stopword
    df_stopword=pd.read_excel("stopword.xlsx")
    stopword_list=df_stopword.to_string()
    filtered_text = [w for w in tokens if not w in stopword_list] 
    
    #stemming
    ps = PorterStemmer()
    stem_text = [ps.stem(token) for token in filtered_text]
    
    return " ".join(stem_text)

def preprocess_call(data):
    
    textword={} # datatype: dictionary
    for i in list(range(data.shape[0])):
        textword[i]=preprocess_alg(data.loc[i,'Text'])
    
    se_preprocessing = pd.Series(textword)  # convert dic to series
    df_preprocessing = se_preprocessing.to_frame(name='Text_tok') # convert series to df

    #join back query id based on index
    df_result_pre=pd.merge(data, df_preprocessing, left_index=True, right_index=True).drop(['Text'],axis=1)
    return df_result_pre

# %% [markdown]
# ## Implementation

# %%
# query
df_query = pd.read_excel("nfdump.xlsx")
# Out:
#   Query id                                               Text
# 0  PLAIN-1  Why Deep Fried Foods May Cause Cancer In the l...
# 1  PLAIN-2  Do Cholesterol Statin Drugs Cause Breast Cance...
# 2  PLAIN-3  Breast Cancer Cells Feed on Cholesterol One in...
# 3  PLAIN-4  Using Diet to Treat Asthma and Eczema I previo...
# 4  PLAIN-5  Treating Asthma With Plants vs. Pills In my vi...

# %%
df_query_pre=preprocess_call(df_query)
df_query_pre.head()
# Out:
#   Query id                                           Text_tok
# 0  PLAIN-1  deep fri food cancer latest studi dietari patt...
# 1  PLAIN-2  cholesterol statin drug breast cancer breast c...
# 2  PLAIN-3  breast cancer cell feed cholesterol american w...
# 3  PLAIN-4  diet treat asthma eczema previous discuss powe...
# 4  PLAIN-5  treat asthma plant pill video treat asthma fru...

# %%
# document
df_doc = pd.read_excel("doc_dump.xlsx")
df_doc_pre=preprocess_call(df_doc)
df_doc_pre
# Out:
#         Doc id                                           Text_tok
# 0        MED-1  birth weight head circumfer prenat exposur acr...
# 1        MED-2  statist regress model estim acrylamid concentr...
# 2        MED-3  chronic intak potato chip human increas produc...
# 3        MED-4  dietari pattern breast cancer risk women pubm ...
# 4        MED-5  empir deriv dietari pattern risk postmenopaus ...
# 5        MED-6  consumpt deep fri food risk prostat cancera ab...
# 6        MED-7  heterocycl amin mutagen carcinogen produc cook...
# 7        MED-8  acrylamid food review scienc futur consider pu...
# 8        MED-9  elev level cholesterol rich lipid raft cancer ...
# 9       MED-10  statin breast cancer surviv nationwid cohort s...
# 10      MED-11  statin risk breast cancer meta analysi observ ...
# 11      MED-12  beta sitosterol enhanc tamoxifen effect breast...
# 12      MED-13  term statin risk ductal lobular breast cancer ...
# 13      MED-14  statin diagnosi breast cancer surviv popul bas...
# 14      MED-15  garden eden plant base diet genet drive conser...
# 15      MED-16  content densiti lipoprotein receptor breast ca...
# 16      MED-17  diet breast cancer understand risk benefit pub...
# 17      MED-18  associ dietari lignan phytoestrogen rich food ...
# 18      MED-19  plant sterol anticanc nutrient evid role breas...
# 19      MED-20  total cholesterol cancer risk larg prospect st...
# 20      MED-21  vegetarian diet amelior symptom atop dermat re...
# 21      MED-22  vegan regimen reduc medic treatment bronchial ...
# 22      MED-23  effect profil cyclosporin patient treat psoria...
# 23      MED-24  dietari polyphenol prevent treatment allerg di...
# 24      MED-25  manipul antioxid intak asthma random control t...
# 25      MED-26  clinic efficaci appl polyphenol treat cedar po...
# 26      MED-27  protect effect fruit veget mediterranean diet ...
# 27      MED-28  evalu clinic efficaci tomato extract perenni a...
# 28      MED-29  prospect studi diet adult onset asthma pubm nc...
# 29      MED-30  effect fresh fruit consumpt lung function whee...
# ...        ...                                                ...
# 5341  MED-5342  vegetarian diet healthi mood state section stu...
# 5342  MED-5343  manag medic mistak ideolog insular account int...
# 5343  MED-5344  risk factor myocardi infarct women men insight...
# 5344  MED-5345  year err human learn pubm ncbi abstract year a...
# 5345  MED-5346  resid duti hour restrict protect aoa critic is...
# 5346  MED-5347  effect health care provid work hour sleep depr...
# 5347  MED-5348  rye lignan human health pubm ncbi abstract rye...
# 5348  MED-5349  rye bread consumpt life reduc risk advanc pros...
# 5349  MED-5350  randomis control short term intervent pilot st...
# 5350  MED-5351  serum enterolacton risk breast cancer case con...
# 5351  MED-5352  intak grain product risk breast cancer hormon ...
# 5352  MED-5353  cancer risk gener immigr sweden pubm ncbi abst...
# 5353  MED-5354  lignan human health pubm ncbi abstract review ...
# 5354  MED-5355  intak grain product risk prostat cancer men da...
# 5355  MED-5356  rye grain bran intak compar refin wheat decrea...
# 5356  MED-5357  rye intak decreas risk human breast cancer abs...
# 5357  MED-5358  plasma urinari alkylresorcinol metabolit poten...
# 5358  MED-5359  milk intak life risk advanc prostat cancer abs...
# 5359  MED-5360  fruit veget antioxid intak lower older adult d...
# 5360  MED-5361  doubl blind random control clinic trial compar...
# 5361  MED-5362  systemat review meta analysi dietari pattern d...
# 5362  MED-5363  dietari pattern depress symptom japanes men wo...
# 5363  MED-5364  chain fatti acid intak fish consumpt suicid co...
# 5364  MED-5365  antioxid antidepress fact fiction pubm ncbi ab...
# 5365  MED-5366  associ mediterranean dietari pattern incid dep...
# 5366  MED-5367  relationship plasma carotenoid depress symptom...
# 5367  MED-5368  suicid mortal relat dietari intak polyunsatur ...
# 5368  MED-5369  suicid mortal european union pubm ncbi abstrac...
# 5369  MED-5370  chain omega fatti acid intak fish consumpt men...
# 5370  MED-5371  omega fatti acid treatment depress systemat re...
#
# [5371 rows x 2 columns]

# %% [markdown]
# ## Preprocess result export

# %%
df_query_pre.to_excel('df_query_pre.xlsx')
df_doc_pre.to_excel('df_doc_pre.xlsx')
